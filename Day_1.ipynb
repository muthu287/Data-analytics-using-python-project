# %% [markdown]
# <a href="https://colab.research.google.com/github/muthu287/Data-analytics-using-python-project/blob/main/Day_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
Mark1 = int(input("Enter Mark 1: "))
Mark2 = int(input("Enter Mark 2: "))
Mark3 = int(input("Enter Mark 3: "))

Total = Mark1 + Mark2 + Mark3
Average = Total/3

print(" Total:", Total)
print(" Average:", Average)

if Average >= 50:
  print("pass")
else:
  print("Fail")
# Out:
# Enter Mark 1: 30
# Enter Mark 2: 80
# Enter Mark 3: 55
#  Total: 165
#  Average: 55.0
# pass

# %%
Expenses = [100, 250, 300, 150]

Total = sum(Expenses)

print( "Expenses:", Expenses)
print("Total Expenses:", Total)
# Out:
# Expenses: [100, 250, 300, 150]
# Total Expenses: 800

# %%
Mark1 = int(input("Enter Mark 1"))
Mark2 = int(input("Enter Mark 2"))
Mark3 = int(input("Enter Mark 3"))

Total = Mark1 + Mark2 + Mark3
Average =  Total/3

print("Total:", Total)
print("Average:", Average)

if Average >= 90:
  print("Grade: A")

elif Average >= 50:
  print("Grade: B")

else:
  print("Grade: c")
# Out:
# Enter Mark 195
# Enter Mark 293
# Enter Mark 390
# Total: 278
# Average: 92.66666666666667
# Grade: A
