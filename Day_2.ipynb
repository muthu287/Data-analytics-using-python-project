# %% [markdown]
# <a href="https://colab.research.google.com/github/muthu287/Data-analytics-using-python-project/blob/main/Day_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def greet():
  print("Hi Internship students")
greet()
# Out:
# Hi Internship students

# %%
def greet(name):
  print("Welcome", name)
greet("Glenda")
# Out:
# Welcome Glenda

# %%
def add(a,b):
  return a+b
result = add(10,20)
print(result)
# Out:
# 30
