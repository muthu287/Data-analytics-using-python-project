# %% [markdown]
# <a href="https://colab.research.google.com/github/muthu287/Data-analytics-using-python-project/blob/main/Day_6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
import pandas as pd

uploaded = files.upload()


df = pd.read_csv('products-100.csv')

print(df.head())
# Out:
#      <input type="file" id="files-3713a7d5-7e7b-45ad-a90b-3e9b96fb42dd" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-3713a7d5-7e7b-45ad-a90b-3e9b96fb42dd">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
print(df.head(2))
# Out:
#    Index                                  Name  \
# 0      1  Compact Printer Air Advanced Digital
# 1      2                                Tablet
#
#                                      Description                    Brand  \
# 0  Situation organization these memory much off.  Garner, Boyle and Flynn
# 1    Discussion loss politics free one thousand.              Mueller Inc
#
#              Category  Price Currency  Stock            EAN        Color  \
# 0  Books & Stationery    265      USD    774  2091465262179  ForestGreen
# 1    Shoes & Footwear    502      USD     81  5286196620740        Black
#
#       Size Availability  Internal ID
# 0    Large    pre_order           56
# 1  8x10 in     in_stock           29

# %%
print(df.info)
# Out:
# <bound method DataFrame.info of     Index                                   Name  \
# 0       1   Compact Printer Air Advanced Digital
# 1       2                                 Tablet
# 2       3                   Smart Blender Cooker
# 3       4           Advanced Router Rechargeable
# 4       5           Portable Mouse Monitor Phone
# ..    ...                                    ...
# 95     96                                 Router
# 96     97     Fast Thermostat Microphone Scooter
# 97     98  Eco Heater Toaster Stove Silent Sense
# 98     99               Clean Blender Scale Lite
# 99    100                             Smart Lamp
#
#                                           Description  \
# 0       Situation organization these memory much off.
# 1         Discussion loss politics free one thousand.
# 2                                   No situation per.
# 3                     For force gas energy six laugh.
# 4   Feeling back religious however author room sci...
# ...

# %%
data = {
    'Name':['john','Mary','David','sri'],
    'Sales':[1000,None,1500,None]

}

df = pd.DataFrame(data)

print(df)
# Out:
#     Name   Sales
# 0   john  1000.0
# 1   Mary     NaN
# 2  David  1500.0
# 3    sri     NaN
