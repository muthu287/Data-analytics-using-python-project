# %% [markdown]
# <a href="https://colab.research.google.com/github/muthu287/Data-analytics-using-python-project/blob/main/Day_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
try:
  num=int(input("enter:"))
  print(num)
except:
  print("Invalid input")
# Out:
# enter:ab
# Invalid input

# %%
import numpy as np
marks=np.array([90,78,99,76,])
print(marks)
# Out:
# [90 78 99 76]

# %%
import numpy as np
students=np.array([
   [90,78],
   [99,76],
   [88,54],
])
print(students)
# Out:
# [[90 78]
#  [99 76]
#  [88 54]]

# %%
import numpy as np
arr=np.zeros((2,3))
print(arr)
# Out:
# [[0. 0. 0.]
#  [0. 0. 0.]]

# %%
import numpy as np
marks=np.array([90,78,99,76])
print(marks[2])
# Out:
# 99

# %%
import numpy as np
marks=np.array([98,88,87,94,66,79,])
print(marks[1:4])
# Out:
# [88 87 94]
